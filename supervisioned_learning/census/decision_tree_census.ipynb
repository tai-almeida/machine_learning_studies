# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
import pickle
with open('census.pkl', 'rb') as f:
    x_training, y_training, x_test, y_test = pickle.load(f)

# %%
x_training.shape, y_training.shape
# Out:
# ((27676, 108), (27676,))

# %%
from sklearn.tree import DecisionTreeClassifier
census_tree = DecisionTreeClassifier(criterion='entropy', random_state=0)
census_tree.fit(x_training, y_training)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
predictions = census_tree.predict(x_test)
predictions
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, classification_report ,confusion_matrix, ConfusionMatrixDisplay
accuracy_score(y_test, predictions)
# Out:
# 0.8104401228249745

# %%
cm = confusion_matrix(y_test, predictions)
conf_matrix = ConfusionMatrixDisplay(cm, display_labels=['<=50K', '>50K'])
conf_matrix.plot()
plt.show()

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.87      0.87      3693
#         >50K       0.61      0.61      0.61      1192
#
#     accuracy                           0.81      4885
#    macro avg       0.74      0.74      0.74      4885
# weighted avg       0.81      0.81      0.81      4885
